# %%
import pandas as pd

# %%
pd.read_csv(https://www.kaggle.com/martinellis/nhl-game-data?select=player_info.csv)
# Out:
#   File "<ipython-input-2-0205b4a1a296>", line 1
#     pd.read_csv(https://www.kaggle.com/martinellis/nhl-game-data?select=player_info.csv)
#                      ^
# SyntaxError: invalid syntax

# %%
pd.read_csv(player_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-02e7801c2897> in <module>
# ----> 1 pd.read_csv(player_info)
#
# NameError: name 'player_info' is not defined

# %%
pd.read_csv(player_info.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f09e6852e235> in <module>
# ----> 1 pd.read_csv(player_info.csv)
#
# NameError: name 'player_info' is not defined

# %%
pd.read_csv(/JeremyScarcella/Downloads/archive (1)/player_info.csv
# Out:
#   File "<ipython-input-5-9d1bcbebc960>", line 1
#     pd.read_csv(/JeremyScarcella/Downloads/archive (1)/player_info.csv
#                 ^
# SyntaxError: invalid syntax

# %%
pd.read_csv(/JeremyScarcella/Downloads/archive(1)/player_info.csv
# Out:
#   File "<ipython-input-8-eef5ecc97c39>", line 1
#     pd.read_csv(/JeremyScarcella/Downloads/archive(1)/player_info.csv
#                 ^
# SyntaxError: invalid syntax

# %%
pd.read_csv("/Users/JeremyScarcella/project-group31-project/player_info.csv")
# Out:
#       player_id firstName      lastName nationality       birthCity  \
# 0       8466148    Marian         Hossa         SVK   Stará Lubovna
# 1       8465058    Michal      Rozsival         CZE          Vlasim
# 2       8476906    Shayne  Gostisbehere         USA  Pembroke Pines
# 3       8466285     Brian      Campbell         CAN       Strathroy
# 4       8470607     Brent      Seabrook         CAN        Richmond
# ...         ...       ...           ...         ...             ...
# 3920    8479374      Adam     Mascherin         CAN           Maple
# 3921    8479403     Tyler       Parsons         USA      Mt. Clemas
# 3922    8480970    Marcus      Hogstrom         SWE            Sveg
# 3923    8477574    Parker        Milner         USA      Pittsburgh
# 3924    8477352      Ryan    Fitzgerald         USA      Boca Raton
#
#      primaryPosition            birthDate birthStateProvince  height  \
# 0                 RW  1979-01-12 00:00:00                NaN   6' 1"
# ...

# %%
pd.read_csv("https://www.kaggle.com/martinellis/nhl-game-data/download")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-de9e5bdfc6de> in <module>
# ----> 1 pd.read_csv("https://www.kaggle.com/martinellis/nhl-game-data/download")
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
url = "https://www.kaggle.com/martinellis/nhl-game-data/download"

# %%
url
# Out:
# 'https://www.kaggle.com/martinellis/nhl-game-data/download'

# %%
pd.read_csv("url")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-22d698239c30> in <module>
# ----> 1 pd.read_csv("url")
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
r = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4c0e59c26507> in <module>
# ----> 1 r = requests.get(url)
#
# NameError: name 'requests' is not defined

# %%
r.headers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9fabc7ff18ca> in <module>
# ----> 1 r.headers
#
# NameError: name 'r' is not defined

# %%
pd.read_csv("https://raw.githubusercontent.com/Ntandrew/skaters.csv/main/skaters.csv")
# Out:
#       playerId  season              name team position situation  \
# 0      8470794    2020      Joe Pavelski  DAL        C     other
# 1      8470794    2020      Joe Pavelski  DAL        C       all
# 2      8470794    2020      Joe Pavelski  DAL        C      5on5
# 3      8470794    2020      Joe Pavelski  DAL        C      4on5
# 4      8470794    2020      Joe Pavelski  DAL        C      5on4
# ...        ...     ...               ...  ...      ...       ...
# 4560   8480001    2020  Urho Vaakanainen  BOS        D     other
# 4561   8480001    2020  Urho Vaakanainen  BOS        D       all
# 4562   8480001    2020  Urho Vaakanainen  BOS        D      5on5
# 4563   8480001    2020  Urho Vaakanainen  BOS        D      4on5
# 4564   8480001    2020  Urho Vaakanainen  BOS        D      5on4
#
#       games_played  icetime  shifts  gameScore  ...  OffIce_F_xGoals  \
# 0               56   2693.0    44.0      51.42  ...             4.41
# ...
