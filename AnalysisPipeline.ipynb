# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Analysis Pipeline

# %% [markdown]
# ## Load Data

# %%
data = pd.read_csv("/Users/JeremyScarcella/project-group31-project/player_info.csv")

# %%
data
# Out:
#       player_id firstName      lastName nationality       birthCity  \
# 0       8466148    Marian         Hossa         SVK   Stará Lubovna
# 1       8465058    Michal      Rozsival         CZE          Vlasim
# 2       8476906    Shayne  Gostisbehere         USA  Pembroke Pines
# 3       8466285     Brian      Campbell         CAN       Strathroy
# 4       8470607     Brent      Seabrook         CAN        Richmond
# ...         ...       ...           ...         ...             ...
# 3920    8479374      Adam     Mascherin         CAN           Maple
# 3921    8479403     Tyler       Parsons         USA      Mt. Clemas
# 3922    8480970    Marcus      Hogstrom         SWE            Sveg
# 3923    8477574    Parker        Milner         USA      Pittsburgh
# 3924    8477352      Ryan    Fitzgerald         USA      Boca Raton
#
#      primaryPosition            birthDate birthStateProvince  height  \
# 0                 RW  1979-01-12 00:00:00                NaN   6' 1"
# 1                  D  1978-09-03 01:00:00                NaN   6' 1"
# 2                  D  1993-04-20 01:00:00                 FL  5' 11"
# 3                  D  1979-05-23 01:00:00                 ON  5' 10"
# 4                  D  1985-04-20 01:00:00                 BC   6' 3"
# ...              ...                  ...                ...     ...
# 3920              LW  1998-06-06 01:00:00                 ON  5' 10"
# 3921               G  1997-09-18 01:00:00                 MI   6' 1"
# 3922               D  1989-03-20 00:00:00                NaN   6' 4"
# 3923               G  1990-09-06 01:00:00                 PA   6' 1"
# 3924               C  1994-10-19 01:00:00                 FL   5' 9"
#
#       height_cm  weight shootsCatches
# 0        185.42   207.0             L
# 1        185.42   210.0             R
# 2        180.34   180.0             L
# 3        177.80   192.0             L
# 4        190.50   220.0             R
# ...         ...     ...           ...
# 3920     177.80   205.0             L
# 3921     185.42   185.0             L
# 3922     193.04   200.0             L
# 3923     185.42   185.0             L
# 3924     175.26   172.0             R
#
# [3925 rows x 12 columns]

# %%
data.dtypes
# Out:
# player_id               int64
# firstName              object
# lastName               object
# nationality            object
# birthCity              object
# primaryPosition        object
# birthDate              object
# birthStateProvince     object
# height                 object
# height_cm             float64
# weight                float64
# shootsCatches          object
# dtype: object

# %%
# Data Delimeters are already set appropriately so there is no need to change them to tab, space or any others, the data is displaying in the correct way.

# %%
# These are the code lines in order to view the entire data set in full
# I am not going to run it as it will take up way to much space

# %%
# pd.set_option('max_columns', None)
# pd.set_option('max_rows', None)

# %% [markdown]
# ## Clean Data

# %%
data.shape
# Out:
# (3925, 12)

# %%
data_cleaned = data.drop(['birthCity','birthDate','birthStateProvince','height'], axis='columns')

# %%
data_cleaned.head(20)
# Out:
#     player_id firstName      lastName nationality primaryPosition  height_cm  \
# 0     8466148    Marian         Hossa         SVK              RW     185.42
# 1     8465058    Michal      Rozsival         CZE               D     185.42
# 2     8476906    Shayne  Gostisbehere         USA               D     180.34
# 3     8466285     Brian      Campbell         CAN               D     177.80
# 4     8470607     Brent      Seabrook         CAN               D     190.50
# 5     8474668      Dale         Weise         CAN              RW     187.96
# 6     8473512    Claude        Giroux         CAN               C     180.34
# 7     8470645     Corey      Crawford         CAN               G     187.96
# 8     8476994    Vinnie    Hinostroza         USA              LW     175.26
# 9     8475323    Marcus        Kruger         SWE               C     182.88
# 10    8473584    Andrew     MacDonald         CAN               D     185.42
# 11    8478055    Gustav      Forsling         SWE               D     182.88
# 12    8478550    Artemi       Panarin         RUS              LW     180.34
# 13    8476177      Matt          Read         CAN              RW     177.80
# 14    8473461     Steve         Mason         CAN               G     193.04
# 15    8475462     Radko         Gudas         CZE               D     182.88
# 16    8476393      Nick       Cousins         CAN               C     180.34
# 17    8479482    Michal        Kempny         CZE               D     182.88
# 18    8469547    Jordin        Tootoo         CAN              RW     175.26
# 19    8474190     Wayne      Simmonds         CAN              RW     187.96
#
#     weight shootsCatches
# 0    207.0             L
# 1    210.0             R
# 2    180.0             L
# 3    192.0             L
# 4    220.0             R
# 5    206.0             R
# 6    185.0             R
# 7    216.0             L
# 8    173.0             R
# 9    186.0             L
# 10   204.0             L
# 11   186.0             L
# 12   168.0             R
# 13   185.0             R
# 14   210.0             R
# 15   204.0             R
# 16   185.0             L
# 17   194.0             L
# 18   195.0             R
# 19   185.0             R

# %%
# As far as I can tell all the data is complete that I will be using and it seems to be correct

# %% [markdown]
# ## Process Data

# %%
# As of know there isnt information we decided that we needed to add to our dataset.
# This may change as we work through the project so in the future we may merge another dataset or add comumns of information.

# %%
data2 = data_cleaned.set_index('primaryPosition')

# %%
data2
# Out:
#                  player_id firstName      lastName nationality  height_cm  \
# primaryPosition
# RW                 8466148    Marian         Hossa         SVK     185.42
# D                  8465058    Michal      Rozsival         CZE     185.42
# D                  8476906    Shayne  Gostisbehere         USA     180.34
# D                  8466285     Brian      Campbell         CAN     177.80
# D                  8470607     Brent      Seabrook         CAN     190.50
# ...                    ...       ...           ...         ...        ...
# LW                 8479374      Adam     Mascherin         CAN     177.80
# G                  8479403     Tyler       Parsons         USA     185.42
# D                  8480970    Marcus      Hogstrom         SWE     193.04
# G                  8477574    Parker        Milner         USA     185.42
# C                  8477352      Ryan    Fitzgerald         USA     175.26
#
#                  weight shootsCatches
# primaryPosition
# RW                207.0             L
# D                 210.0             R
# D                 180.0             L
# D                 192.0             L
# D                 220.0             R
# ...                 ...           ...
# LW                205.0             L
# G                 185.0             L
# D                 200.0             L
# G                 185.0             L
# C                 172.0             R
#
# [3925 rows x 7 columns]

# %%
# Changed the player postion to the index as it will make for easier data analysis

# %%
data2.rename(index = {"G": "Goalie",
                     "D":"Defence",
                      "RW":"Right Wing",
                      "LW":"Left Wing",
                      "C":"Center"},
                                 inplace = True)

# %%
data2
# Out:
#                  player_id firstName      lastName nationality  height_cm  \
# primaryPosition
# Right Wing         8466148    Marian         Hossa         SVK     185.42
# Defence            8465058    Michal      Rozsival         CZE     185.42
# Defence            8476906    Shayne  Gostisbehere         USA     180.34
# Defence            8466285     Brian      Campbell         CAN     177.80
# Defence            8470607     Brent      Seabrook         CAN     190.50
# ...                    ...       ...           ...         ...        ...
# Left Wing          8479374      Adam     Mascherin         CAN     177.80
# Goalie             8479403     Tyler       Parsons         USA     185.42
# Defence            8480970    Marcus      Hogstrom         SWE     193.04
# Goalie             8477574    Parker        Milner         USA     185.42
# Center             8477352      Ryan    Fitzgerald         USA     175.26
#
#                  weight shootsCatches
# primaryPosition
# Right Wing        207.0             L
# Defence           210.0             R
# Defence           180.0             L
# Defence           192.0             L
# Defence           220.0             R
# ...                 ...           ...
# Left Wing         205.0             L
# Goalie            185.0             L
# Defence           200.0             L
# Goalie            185.0             L
# Center            172.0             R
#
# [3925 rows x 7 columns]

# %%
# Also renamed the titles of the index player positions for an easier data analysis

# %% [markdown]
# ## Wrangle Data

# %%
# At this point wrangling data will not beenfit us greatly and to some degree the dataset has seen changes such as changing the index column that can be counted as wrangling data
