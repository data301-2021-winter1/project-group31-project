# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('max_columns', None)

# %%
pd.set_option('max_rows', None)

# %%
pd.read_csv("https://raw.githubusercontent.com/data301-2021-winter1/project-group31-project/main/data/raw/player_info.csv?token=AVQ3DF3SUN5ZGIGYR5ZNV33BM45R6")
# Out:
#       player_id       firstName             lastName nationality  \
# 0       8466148          Marian                Hossa         SVK
# 1       8465058          Michal             Rozsival         CZE
# 2       8476906          Shayne         Gostisbehere         USA
# 3       8466285           Brian             Campbell         CAN
# 4       8470607           Brent             Seabrook         CAN
# 5       8474668            Dale                Weise         CAN
# 6       8473512          Claude               Giroux         CAN
# 7       8470645           Corey             Crawford         CAN
# 8       8476994          Vinnie           Hinostroza         USA
# 9       8475323          Marcus               Kruger         SWE
# 10      8473584          Andrew            MacDonald         CAN
# 11      8478055          Gustav             Forsling         SWE
# 12      8478550          Artemi              Panarin         RUS
# ...
